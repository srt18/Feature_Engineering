# %% [markdown]
# # Handling Missing Categorical Missing Data
# ![image.png](attachment:4bbdcd06-9b73-4312-8e77-a45377aee76a.png)

# %% [markdown]
# ## MCAR (Missing Completely at Randoom)
# ![image.png](attachment:f2b29d41-33cd-4f22-b21f-0331c8268437.png)
# ![image.png](attachment:c3a29c0c-c93b-4a68-b336-d03ae71af71d.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train_d37.csv',usecols=['GarageQual','FireplaceQu','SalePrice'])

# %%
df.head(5)
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500
# 3          Gd         TA     140000
# 4          TA         TA     250000

# %%
df.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
df['GarageQual'].value_counts().sort_values(ascending=False).plot.bar()
plt.xlabel('GarageQual')
plt.ylabel('Number of houses')
# Out:
# Text(0, 0.5, 'Number of houses')

# %%
df['GarageQual'].fillna('Missing',inplace=True)

# %%
df['GarageQual'].value_counts().sort_values(ascending=False).plot.bar()
plt.xlabel('GarageQual')
plt.ylabel('Number of houses')
# Out:
# Text(0, 0.5, 'Number of houses')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['SalePrice']),df['SalePrice'],test_size=0.2)

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='constant',fill_value='Missing')

# %%
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_train)
# Out:
# C:\Users\trukk\miniconda3\envs\myenv\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(

# %%
imputer.statistics_
# Out:
# array(['Missing', 'Missing'], dtype=object)
